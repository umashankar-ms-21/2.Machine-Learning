# %%
# Pandas is a library and it contains various functions related to the database. 
import pandas as pd

# %%
# Dataset is called to read csv file under pandas function so that to assigned the variable name as "dataset"
dataset = pd.read_csv("Salary_Data.csv")
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
# Independent is an input variable name assigned to call the YearsExperience column from the dataset
independent = dataset[["YearsExperience"]]
independent
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
# dependent is an output variable name assigned to call the "Salary" column from the dataset
dependent = dataset[["Salary"]]
dependent
# Out:
#       Salary
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# 28  122391.0
# 29  121872.0

# %%
# matplotlib is a library and it is used to graphical representation of a data points on a coordinate system.
import matplotlib.pyplot as plt

# the dataset is in two dimentional data hence it can be plot in graphical to know the algorithm
plt.scatter(independent, dependent)         # scatter refers to a type of data visualization
plt.xlabel("YearsExperience", fontsize=20) # xlabel is an assigned label for the input("YearsExperience") from dataset to plot horizental x axes
plt.ylabel("Salary", fontsize=20)         # ylabel is an assigned label for the output("Salary") from dataset to plot in vertical y axes
plt.show()                               # show() is a built in function of matplotlib library for visualization representation

# %%
# train_test_split is one of the function imported from sklearn library to test and train the input and output data 
# for Machine Learning model creation.
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size=1/3, random_state=0) 
# seperate variables assigning to train and test on x & y axes by providing both input(x_train,x_test) & output(y_train,y_test) respectively
# to apply this on model and the proportionate test_size ratio as 1/3.

# %%
y_test # print the y_test output
# Out:
#       Salary
# 2    37731.0
# 28  122391.0
# 13   57081.0
# 10   63218.0
# 26  116969.0
# 24  109431.0
# 27  112635.0
# 11   55794.0
# 17   83088.0

# %%
# LinearRegression is called a buit-in function imported from the sklearn library for model creation
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()  # regressor is an assingned variable name for non-parameterised LinearRegression class
regressor.fit(x_train,y_train)  # the trained x & y axes variables applied on this linear_model using the LinearRegression function ".fit()"
# Out:
# LinearRegression()

# %%
# to print and view the b1 and b0 value as already calculated the weight/slope and bais/initial value when the model trained

weight = regressor.coef_  # .coef_ go and search the estimated value of weight from the object regressor while the model trained
print("weight of the model={}".format(weight)) # in python format(weight) method looks the curly braces inside the strings and replace the value of weight

bais = regressor.intercept_  # .intercept_ go and search the estimated initial value from the object regressor while the model trained
print("intercept of the model={}".format(bais)) # in python format(bais) method looks the curly braces inside the strings and replace the intercept value
# Out:
# weight of the model=[[9345.94244312]]
# intercept of the model=[26816.19224403]

# %%
# to know the y_pred by passing the input x_test  
y_pred = regressor.predict(x_test) #.predict(x_test) will search the x_test data from regressor object to predict the output(y_pred)
y_pred
# Out:
# array([[ 40835.10590871],
#        [123079.39940819],
#        [ 65134.55626083],
#        [ 63265.36777221],
#        [115602.64545369],
#        [108125.8914992 ],
#        [116537.23969801],
#        [ 64199.96201652],
#        [ 76349.68719258],
#        [100649.1375447 ]])

# %%
# importing the r2_score multiple formula functions from the sklearn.metrics class 
from sklearn.metrics import r2_score
r_score = r2_score(y_test, y_pred) # to evaluate the model on metrics by applying the actual output(y_test) and predicted output(y_pred) on
                                     # the formula r2_score to check the r_score meets to 1

# %%
r_score  # the r_score meets near to 1 hence this model is the best model to save instead of train the another model
# Out:
# 0.9749154407708353

# %%
# pickle is a library to save the best model after evaluated or tested on metrics. 
import pickle
filename = "finalised_linear_model.sav"  # filename is a variable name for "finalised_linear_model" to save the created model  
pickle.dump(regressor, open(filename, 'wb')) # by this expression allows to save the created model as filename variable with "write binary"

# %%
# by loading the finalised model and enter the user input on "x" to get the predicted output
loaded_model = pickle.load(open("finalised_linear_model.sav", 'rb'))  # the saved model by using this ".load(open())" built-in function
                                                         # can be accessed in new jupyter notebook without copying all the above codes.
result = loaded_model.predict([[15]])  # by enter the user input as 15 on 'x' to predict the 'y' value
result  # predicted value assigned on result vairable to view the predicted output
# Out:
# C:\Users\admin\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[167005.32889087]])
