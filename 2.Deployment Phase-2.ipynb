# %%
import pickle  # pickle is a built-in function used for serializing and deserializing object structures.

# %%
#Stored the results of expensive computations so they can be quickly retrieved without re-calculating them.
loaded_model=pickle.load(open("finalised_model_linear.sav", "rb"))
result = loaded_model.predict([[13]]) # user entered input of '0' experience or fresher to predict the salary.
result # the result of y_pred value is same with the intercept value of the model i.e."initial value(b0)" of standard linear equation: y=b1x+b0
# Out:
# C:\Users\admin\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[148313.44400462]])

# %%
# input received from the enduser
prediction_input = int(input("Enter the Prediction input value:"))
# Out:
# Enter the Prediction input value: 0

# %%
# passing the input through the created model to predict the output  
Future_Prediction = loaded_model.predict([[prediction_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[[26816.19224403]]
# C:\Users\admin\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
