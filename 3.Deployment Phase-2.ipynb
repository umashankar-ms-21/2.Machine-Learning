# %%
# Load the saved model
import pickle
loaded_model = pickle.load(open("finalized_model_Mul_Linear.sav", 'rb')) 
#'rb' is read binary to open the trained model in any where without script

# %%
# Prepare a "new" startup for prediction
result = loaded_model.predict([[165000, 135000, 470000, 0, 1]]) # # Note: Ensure these match the exact order/count of columns used during .fit()
# Out:
# C:\Users\admin\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result # view the predicted profit fro New York city
# Out:
# array([[191850.86533719]])
